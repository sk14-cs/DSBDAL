# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\SSOS19\\Documents\\SP.csv")

# %%
df
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 0  female        70.0             84           82.0             84.0
# 1  female        71.0             70           77.0              NaN
# 2  female        61.0             90           89.0             84.0
# 3    male        66.0             74            NaN             80.0
# 4    male        70.0             87           66.0             91.0
# 5  female        69.0             70           88.0             81.0
# 6    male        80.0             84           67.0             93.0
# 7    male         NaN             87           66.0             97.0
# 8    male        78.0             82           70.0             98.0
#
#    placement offer count  region
# 0                      2    PUNE
# 1                      3      na
# 2                      2  nashik
# 3                      2      Na
# 4                      3    pune
# 5                      2      na
# 6                      3  nashik
# 7                      3    pune
# 8                      3     NaN

# %%
df.isnull()
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 0   False       False          False          False            False
# 1   False       False          False          False             True
# 2   False       False          False          False            False
# 3   False       False          False           True            False
# 4   False       False          False          False            False
# 5   False       False          False          False            False
# 6   False       False          False          False            False
# 7   False        True          False          False            False
# 8   False       False          False          False            False
#
#    placement offer count  region
# 0                  False   False
# 1                  False   False
# 2                  False   False
# 3                  False   False
# 4                  False   False
# 5                  False   False
# 6                  False   False
# 7                  False   False
# 8                  False    True

# %%
series = pd.isnull(df["math score"])
df[series]
# Out:
#   gender  math score  reading score  writing score  placement score  \
# 7   male         NaN             87           66.0             97.0
#
#    placement offer count region
# 7                      3   pune

# %%
df.notnull()
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 0    True        True           True           True             True
# 1    True        True           True           True            False
# 2    True        True           True           True             True
# 3    True        True           True          False             True
# 4    True        True           True           True             True
# 5    True        True           True           True             True
# 6    True        True           True           True             True
# 7    True       False           True           True             True
# 8    True        True           True           True             True
#
#    placement offer count  region
# 0                   True    True
# 1                   True    True
# 2                   True    True
# 3                   True    True
# 4                   True    True
# 5                   True    True
# 6                   True    True
# 7                   True    True
# 8                   True   False

# %%
series1 = pd.notnull(df["math score"])
df[series1]
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 0  female        70.0             84           82.0             84.0
# 1  female        71.0             70           77.0              NaN
# 2  female        61.0             90           89.0             84.0
# 3    male        66.0             74            NaN             80.0
# 4    male        70.0             87           66.0             91.0
# 5  female        69.0             70           88.0             81.0
# 6    male        80.0             84           67.0             93.0
# 8    male        78.0             82           70.0             98.0
#
#    placement offer count  region
# 0                      2    PUNE
# 1                      3      na
# 2                      2  nashik
# 3                      2      Na
# 4                      3    pune
# 5                      2      na
# 6                      3  nashik
# 8                      3     NaN

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['gender'] = le.fit_transform(df['gender'])
newdf=df

# %%
df
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 0       0        70.0             84           82.0             84.0
# 1       0        71.0             70           77.0              NaN
# 2       0        61.0             90           89.0             84.0
# 3       1        66.0             74            NaN             80.0
# 4       1        70.0             87           66.0             91.0
# 5       0        69.0             70           88.0             81.0
# 6       1        80.0             84           67.0             93.0
# 7       1         NaN             87           66.0             97.0
# 8       1        78.0             82           70.0             98.0
#
#    placement offer count  region
# 0                      2    PUNE
# 1                      3      na
# 2                      2  nashik
# 3                      2      Na
# 4                      3    pune
# 5                      2      na
# 6                      3  nashik
# 7                      3    pune
# 8                      3     NaN

# %%
missing_values = ["Na", "na"]
df = pd.read_csv("C:\\Users\\SSOS19\\Documents\\SP.csv", na_values =missing_values)
df
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 0  female        70.0             84           82.0             84.0
# 1  female        71.0             70           77.0              NaN
# 2  female        61.0             90           89.0             84.0
# 3    male        66.0             74            NaN             80.0
# 4    male        70.0             87           66.0             91.0
# 5  female        69.0             70           88.0             81.0
# 6    male        80.0             84           67.0             93.0
# 7    male         NaN             87           66.0             97.0
# 8    male        78.0             82           70.0             98.0
#
#    placement offer count  region
# 0                      2    PUNE
# 1                      3     NaN
# 2                      2  nashik
# 3                      2     NaN
# 4                      3    pune
# 5                      2     NaN
# 6                      3  nashik
# 7                      3    pune
# 8                      3     NaN

# %%
ndf=df
ndf.fillna(0)
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 0  female        70.0             84           82.0             84.0
# 1  female        71.0             70           77.0              0.0
# 2  female        61.0             90           89.0             84.0
# 3    male        66.0             74            0.0             80.0
# 4    male        70.0             87           66.0             91.0
# 5  female        69.0             70           88.0             81.0
# 6    male        80.0             84           67.0             93.0
# 7    male         0.0             87           66.0             97.0
# 8    male        78.0             82           70.0             98.0
#
#    placement offer count  region
# 0                      2    PUNE
# 1                      3       0
# 2                      2  nashik
# 3                      2       0
# 4                      3    pune
# 5                      2       0
# 6                      3  nashik
# 7                      3    pune
# 8                      3       0

# %%
m_v=df['math score'].mean()
df['math score'].fillna(value=m_v, inplace=True)
df
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 0  female      70.000             84           82.0             84.0
# 1  female      71.000             70           77.0              NaN
# 2  female      61.000             90           89.0             84.0
# 3    male      66.000             74            NaN             80.0
# 4    male      70.000             87           66.0             91.0
# 5  female      69.000             70           88.0             81.0
# 6    male      80.000             84           67.0             93.0
# 7    male      70.625             87           66.0             97.0
# 8    male      78.000             82           70.0             98.0
#
#    placement offer count  region
# 0                      2    PUNE
# 1                      3     NaN
# 2                      2  nashik
# 3                      2     NaN
# 4                      3    pune
# 5                      2     NaN
# 6                      3  nashik
# 7                      3    pune
# 8                      3     NaN

# %%
ndf.replace(to_replace = np.nan, value = -99)
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 0  female      70.000             84           82.0             84.0
# 1  female      71.000             70           77.0            -99.0
# 2  female      61.000             90           89.0             84.0
# 3    male      66.000             74          -99.0             80.0
# 4    male      70.000             87           66.0             91.0
# 5  female      69.000             70           88.0             81.0
# 6    male      80.000             84           67.0             93.0
# 7    male      70.625             87           66.0             97.0
# 8    male      78.000             82           70.0             98.0
#
#    placement offer count  region
# 0                      2    PUNE
# 1                      3     -99
# 2                      2  nashik
# 3                      2     -99
# 4                      3    pune
# 5                      2     -99
# 6                      3  nashik
# 7                      3    pune
# 8                      3     -99

# %%
ndf.dropna()
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 0  female      70.000             84           82.0             84.0
# 2  female      61.000             90           89.0             84.0
# 4    male      70.000             87           66.0             91.0
# 6    male      80.000             84           67.0             93.0
# 7    male      70.625             87           66.0             97.0
#
#    placement offer count  region
# 0                      2    PUNE
# 2                      2  nashik
# 4                      3    pune
# 6                      3  nashik
# 7                      3    pune

# %%
ndf.dropna(how = 'all')
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 0  female      70.000             84           82.0             84.0
# 1  female      71.000             70           77.0              NaN
# 2  female      61.000             90           89.0             84.0
# 3    male      66.000             74            NaN             80.0
# 4    male      70.000             87           66.0             91.0
# 5  female      69.000             70           88.0             81.0
# 6    male      80.000             84           67.0             93.0
# 7    male      70.625             87           66.0             97.0
# 8    male      78.000             82           70.0             98.0
#
#    placement offer count  region
# 0                      2    PUNE
# 1                      3     NaN
# 2                      2  nashik
# 3                      2     NaN
# 4                      3    pune
# 5                      2     NaN
# 6                      3  nashik
# 7                      3    pune
# 8                      3     NaN

# %%
ndf.dropna(axis = 1)
# Out:
#    gender  math score  reading score  placement offer count
# 0  female      70.000             84                      2
# 1  female      71.000             70                      3
# 2  female      61.000             90                      2
# 3    male      66.000             74                      2
# 4    male      70.000             87                      3
# 5  female      69.000             70                      2
# 6    male      80.000             84                      3
# 7    male      70.625             87                      3
# 8    male      78.000             82                      3

# %%
new_data = ndf.dropna(axis = 0, how ='any')
new_data
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 0  female      70.000             84           82.0             84.0
# 2  female      61.000             90           89.0             84.0
# 4    male      70.000             87           66.0             91.0
# 6    male      80.000             84           67.0             93.0
# 7    male      70.625             87           66.0             97.0
#
#    placement offer count  region
# 0                      2    PUNE
# 2                      2  nashik
# 4                      3    pune
# 6                      3  nashik
# 7                      3    pune

# %%
col = ['math score', 'reading score' , 'writing score','placement score']
df.boxplot(col)
# Out:
# <Axes: >

# %%
print(np.where(df['math score']>90))
print(np.where(df['reading score']<25))
print(np.where(df['writing score']<30))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df['placement score'], df['placement offer count'])
plt.show()

# %%
print(np.where((df['placement score']<50) & (df['placement offer count']>1)))
print(np.where((df['placement score']>85) & (df['placement offer count']<3)))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
from scipy import stats

# %%
z = np.abs(stats.zscore(df['math score']))

# %%
print(z)
# Out:
# 0    0.116311
# 1    0.069786
# 2    1.791182
# 3    0.860698
# 4    0.116311
# 5    0.302407
# 6    1.744658
# 7    0.000000
# 8    1.372464
# Name: math score, dtype: float64

# %%
threshold = 0.18

# %%
sample_outliers = np.where(z <threshold)
sample_outliers
# Out:
# (array([0, 1, 4, 7], dtype=int64),)

# %%
sorted_rscore= sorted(df['reading score'])

# %%
sorted_rscore
# Out:
# [70, 70, 74, 82, 84, 84, 87, 87, 90]

# %%
q1 = np.percentile(sorted_rscore, 25)

# %%
q3 = np.percentile(sorted_rscore, 75)
print(q1,q3)
# Out:
# 74.0 87.0

# %%
IQR = q3-q1

# %%
lwr_bound = q1-(1.5*IQR)
upr_bound = q3+(1.5*IQR)
print(lwr_bound, upr_bound)
# Out:
# 54.5 106.5

# %%
r_outliers = []
for i in sorted_rscore:
 if (i<lwr_bound or i>upr_bound):
   r_outliers.append(i)
print(r_outliers)
# Out:
# []

# %%
new_df=df
for i in sample_outliers:
  new_df.drop(i,inplace=True)
new_df
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 2  female        61.0             90           89.0             84.0
# 3    male        66.0             74            NaN             80.0
# 5  female        69.0             70           88.0             81.0
# 6    male        80.0             84           67.0             93.0
# 8    male        78.0             82           70.0             98.0
#
#    placement offer count  region
# 2                      2  nashik
# 3                      2     NaN
# 5                      2     NaN
# 6                      3  nashik
# 8                      3     NaN

# %%
df_stud=df
ninetieth_percentile = np.percentile(df_stud['math score'], 90)
b = np.where(df_stud['math score']>ninetieth_percentile,
ninetieth_percentile, df_stud['math score'])
print("New array:",b)
# Out:
# New array: [61.  66.  69.  79.2 78. ]

# %%
df_stud.insert(1,"m score",b,True)
df_stud
# Out:
#    gender  m score  math score  reading score  writing score  placement score  \
# 2  female     61.0        61.0             90           89.0             84.0
# 3    male     66.0        66.0             74            NaN             80.0
# 5  female     69.0        69.0             70           88.0             81.0
# 6    male     79.2        80.0             84           67.0             93.0
# 8    male     78.0        78.0             82           70.0             98.0
#
#    placement offer count  region
# 2                      2  nashik
# 3                      2     NaN
# 5                      2     NaN
# 6                      3  nashik
# 8                      3     NaN

# %%
col = ['reading score']
df.boxplot(col)
# Out:
# <Axes: >

# %%
median=np.median(sorted_rscore)
median
# Out:
# 84.0

# %%
refined_df=df

# %%
refined_df['reading score'] = np.where(refined_df['reading score'] >upr_bound, median,refined_df['reading score'])

# %%
refined_df['reading score'] = np.where(refined_df['reading score'] <lwr_bound, median,refined_df['reading score'])

# %%
col = ['reading score']
refined_df.boxplot(col)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
new_df['math score'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['log_math'] = np.log10(df['math score'])

# %%
df['log_math'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt

# %%
df['log_math'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>
